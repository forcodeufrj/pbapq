# %%
pHs = [1, 2, 3]
razoes_ao = [0.5, 1, 2]
concentracao_exts = [0.17, 0.26, 0.35]

for pH in pHs:
    for razao_ao in razoes_ao:
        for concentracao_ext in concentracao_exts:
            print(str(pH) + '...........' + str(razao_ao) + '............' +str(concentracao_ext))
# Out:
# 1...........0.5............0.17
# 1...........0.5............0.26
# 1...........0.5............0.35
# 1...........1............0.17
# 1...........1............0.26
# 1...........1............0.35
# 1...........2............0.17
# 1...........2............0.26
# 1...........2............0.35
# 2...........0.5............0.17
# 2...........0.5............0.26
# 2...........0.5............0.35
# 2...........1............0.17
# 2...........1............0.26
# 2...........1............0.35
# 2...........2............0.17
# 2...........2............0.26
# 2...........2............0.35
# 3...........0.5............0.17
# 3...........0.5............0.26
# 3...........0.5............0.35
# 3...........1............0.17
# 3...........1............0.26
# 3...........1............0.35
# 3...........2............0.17
# 3...........2............0.26
# 3...........2............0.35

# %%
temperaturas = [300 + 3*x for x in range(1, 100)] # K
pressoes = [1e5*x for x in range(1, 100)] # Pa
n = 1 # mol
R = 8.314 # J/mol/K

# %%
def calculaVolumes(temperaturas, pressoes):
    
    volumes = []
    for T in temperaturas:
        linha = []
        
        for P in pressoes:
            volume = n*R*T/P
            linha.append(volume)
        
        volumes.append(linha)
    
    return volumes

# %%
volumes = calculaVolumes(temperaturas, pressoes)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d.axes3d import Axes3D
import numpy as np

temperaturas_grid, pressoes_grid = np.meshgrid(temperaturas, pressoes)
volumes_grid = np.array(calculaVolumes(temperaturas, pressoes)).T

# %%
fig = plt.figure(figsize=(20,6))    
ax1 = fig.add_subplot(1, 2, 1, projection='3d')
p1 = ax1.plot_surface(temperaturas_grid, pressoes_grid, volumes_grid, cmap=mpl.cm.plasma, rstride=1, cstride=1, linewidth=0)
ax1.set_xlabel('T(K)')
ax1.set_ylabel('P(Pa)')
ax1.set_zlabel('V(m³)')
ax1.view_init(15, 20)
